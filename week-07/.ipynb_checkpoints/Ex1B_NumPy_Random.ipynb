# %% [markdown]
# #Exercise 1.B NumPy Random

# %%
import numpy as numpy

# %% [markdown]
# ##Generating Random Numbers

# %%
r_1 = np.random.randint(1, 21, size=2)

print(r_1)

# %%
r_2 = np.random.randint(1, 21, size=(1, 2))

print(r_2)

# %%
r_3 = np.random.rand(2, 1)

print(r_3)

# %%
r_4 = np.random.randint(20, 101, size=(4, 5))

print(r_4)

# %%
r_5 = np.random.rand(4, 5)

print(r_5)

# %% [markdown]
# ##Generating Random Choices from an Array

# %%
students = np.array([
    "Alexus", "Naomi", "Victoria", "Corey",
    "Alondra", "Luis A.", "Luis O.", "Blake",
    "Sonia", "Lorah", "Smaya", "Daniel"
])

print(students)

# %%
call_on = np.random.choice(students)

print(call_on)

# %%
breakout_groups = np.random.choice(students, size=(3, 4))

print(breakout_groups)

# This may not be the best way to assign breakout groups
# because the same student can appear more than once,
# while some students may not appear at all.

# %%
call_on_weighted = np.random.choice(
    students,
    size=5,
    p=[0.30, 0.10, 0.05, 0.10,
       0.05, 0.10, 0.00, 0.05,
       0.05, 0.05, 0.10, 0.05]
)

print(call_on_weighted)

# Probability explanation:
# Alexus has a 30% chance of being selected.
# Luis O, has a 0% chance and will never be selected.
# The remaining students have smaller probability values.
# All probability values together must add up to 1.0.

# %% [markdown]
# ##Generating a Normal Distribution

# %%
bell_curve = np.random.normal(loc=10, scale=5, size=(4, 5))

print(bell_curve)
